# %%
#reeborg maze
def my_right():
    turn_left()
    turn_left()
    turn_left()

def check():
     
  if right_is_clear():
    my_right()
    move()
  elif front_is_clear():
    move()
  elif wall_on_right():
    turn_left()
  elif wall_in_front():
    my_right()
  
  
        
            
while not at_goal():
    check()
